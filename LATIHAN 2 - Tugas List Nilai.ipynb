# %%
import random

# GENERATE RANDOM
nilaiTugas = []
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))

print(nilaiTugas,'\n')

# TAMPILKAN:
# ganjil
nilai_ganjil=''
for j in nilaiTugas:
    if j%2!=0:
        nilai_ganjil=nilai_ganjil+str(j)+' '
print('1. Nilai Ganjil: ', nilai_ganjil)
        
# nilai > 70
jumlah_nilai_70=0
for k in nilaiTugas:
    if k>70:
        jumlah_nilai_70+=1
print('2. Jumlah Nilai yang Lebih Besar 70: %i angka' % jumlah_nilai_70)

# standar deviasi
import math
total_nilai=0
nilai_rata2=0
jml_elemen_nilai=len(nilaiTugas)
nilai_stddev=0

for a in nilaiTugas:
    total_nilai+=a
nilai_rata2=total_nilai/jml_elemen_nilai

# print(nilai_rata2)

for b in nilaiTugas:
    nilai_stddev=((b-nilai_rata2)**2)/jml_elemen_nilai

# print(nilai_stddev)
nilai_stddev=math.sqrt(nilai_stddev)
print('3. Nilai Standar Deviasi: ', nilai_stddev)

# maksimum
nilai_max=0
for c in nilaiTugas:
    if nilai_max==0 or nilai_max<c:
        nilai_max=c
print('4. Nilai Maksimum: ',nilai_max)

# minimum
nilai_min=0
for d in nilaiTugas:
    if nilai_min==0 or nilai_min>d:
        nilai_min=d
print('5. Nilai Minimum: ',nilai_min)

# modus
dict1={}
#loop1 - import nilai ke dict
for i in nilaiTugas:
    dict1[i]=0

#loop2 - count nilai dictionary-nya
for j in nilaiTugas:
    if dict1[j] in nilaiTugas:
        dict1[j]+=1
    else:
        dict1[j]=1
# print(dict1)

#cari nilai value max
val_max=0
for k in dict1.values():
    if val_max<k:
        val_max=k
# print('val max: ',val_max)

print('6. Nilai Modus: ', end="")
for l,m in dict1.items():
    if m==val_max:
        print(l, end=" ")
# Out:
# [8, 85, 54, 36, 58, 32, 2, 82, 76, 26, 91, 50, 4, 73, 29, 85, 16, 87, 52, 80, 65, 63, 41, 85, 18, 81, 58, 21, 91, 85, 58, 57, 60, 9, 34, 23, 72, 3, 2, 18, 55, 25, 8, 57, 72, 57, 99, 53, 15, 46, 11, 23, 44, 6, 56, 10, 14, 68, 6, 60, 52, 18, 55, 39, 34, 16, 91, 74, 38, 19, 44, 74, 45, 39, 28, 23, 86, 5, 63, 43, 47, 63, 65, 27, 45, 87, 16, 36, 20, 18, 53, 51, 64, 98, 35, 35, 55, 16, 13, 1, 1, 72, 55, 77, 10, 16, 85, 80, 65, 64, 76, 3, 15, 46, 98, 34, 95, 68, 38, 93, 63, 36, 28, 22, 93, 36, 50, 22, 87, 53, 78, 51, 58, 54, 22, 78, 82, 73, 79, 54, 87, 49, 48, 29, 49, 90, 9, 37, 45, 33, 23, 37, 86, 28, 13, 42, 60, 70, 31, 98, 41, 90, 88, 54, 92, 23, 60, 23, 38, 41, 71, 32, 1, 18, 20, 36, 49, 10, 20, 62, 87, 99, 92, 21, 38, 99, 64, 5, 41, 75, 50, 30, 9, 84, 54, 30, 70, 46, 50, 40, 69, 1, 23, 13, 83, 48, 90, 51, 45, 32, 52, 19, 34, 91, 70, 43, 21, 13, 40, 51, 89, 4, 96, 8, 16, 16, 3, 41, 96, 78, 40, 38, 97, 23, 67, 23, 37, 22, 95, 12, 19, 73, 12, 67, 56, 76, 73, 80, 74, 83]
#
# 1. Nilai Ganjil:  85 91 73 29 85 87 65 63 41 85 81 21 91 85 57 9 23 3 55 25 57 57 99 53 15 11 23 55 39 91 19 45 39 23 5 63 43 47 63 65 27 45 87 53 51 35 35 55 13 1 1 55 77 85 65 3 15 95 93 63 93 87 53 51 73 79 87 49 29 49 9 37 45 33 23 37 13 31 41 23 23 41 71 1 49 87 99 21 99 5 41 75 9 69 1 23 13 83 51 45 19 91 43 21 13 51 89 3 41 97 23 67 23 37 95 19 73 67 73 83
# 2. Jumlah Nilai yang Lebih Besar 70: 65 angka
# 3. Nilai Standar Deviasi:  2.20954664671285
# 4. Nilai Maksimum:  99
# 5. Nilai Minimum:  1
# 6. Nilai Modus: 16
